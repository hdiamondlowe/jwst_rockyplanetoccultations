# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
import astropy.units as u
from astropy.table import Table, vstack, unique
from astropy.time import Time
import astrotools.orbitparams as orb

import starry as st
st.config.lazy = False
st.config.quiet = True

# %%
# Creating a standard star
def make_star(targ):
    M_s  = targ['st_mass']
    R_s  = targ['st_rad']
    prot = 1

    star = st.Primary(
        st.Map(ydeg = 1, udeg = 2, nw = 1, amp = 1.0), 
        m    = M_s,
        r    = R_s, 
        prot = prot
    )

    return star

# creating a planet; 
# adapted from Mette's code
def make_planet(targ, tidally_locked=True):

    planet  = st.kepler.Secondary(
        st.Map(ydeg = 5, nw = 1, amp = 1e-4),               
        m      = targ['pl_bmasse'],
        r      = targ['pl_rade'],
        porb   = targ['pl_orbper'],                                                      
        prot   = targ['pl_orbper'],                                       
        Omega  = 0,                                         
        ecc    = 0,                                                         
        w      = 90,                                  
        t0     = targ['pl_tranmid'],                           
        theta0 = 0,                           
        inc    = targ['pl_orbincl'],
        length_unit = u.Rearth,
        mass_unit   = u.Mearth

    )
    
    if tidally_locked:
        planet.map.spot(contrast = -1, radius = 60)
        
    return planet

# %%
sample = ascii.read('sample_final.csv')
sample
# Out:
# <Table length=9>
#  hostname   pl_name   sy_dist    rastr     ... filter subarray  nobs
#    str9      str11    float64    str12     ...  str6    str6   int64
# --------- ----------- ------- ------------ ... ------ -------- -----
#   GJ 3473   GJ 3473 b 27.3644 08h02m22.47s ... f1500w   sub256     1
#    GJ 357    GJ 357 b 9.44181 09h36m01.79s ... f1500w   sub256     1
# HD 260655 HD 260655 b 10.0055 06h37m09.97s ... f1500w   sub256     1
#   L 98-59   L 98-59 c 10.6194 08h18m07.89s ... f1500w   sub256     1
#  LHS 1140  LHS 1140 c 14.9861 00h44m59.67s ... f1500w   sub256     1
#  LHS 1478  LHS 1478 b 18.2276 02h57m21.33s ... f1500w   sub256     1
#  LTT 3780  LTT 3780 b 21.9814 10h18m34.78s ... f1500w   sub256     1
#  TOI-1468  TOI-1468 b 24.7399 01h06m36.93s ... f1500w   sub256     1
#   TOI-270   TOI-270 b 22.4793 04h33m39.86s ... f1500w   sub256     1

# %%
planetSystems = ascii.read('../planet_conjunctions/NASAExoArchive_ExoplanetTable.dat')

# %%
# clean up individual planets
ind = np.argwhere(planetSystems['hostname'] == 'TRAPPIST-1')
planetSystems['st_raderr1'][ind] = 0.0013  # Agol+ 2020
planetSystems['st_raderr2'][ind] = -0.0013  # Agol+ 2020
planetSystems['st_mass'][ind] = 0.0898  # Mann+ 2019

ind = np.argwhere(planetSystems['hostname'] == 'LHS 1140')
planetSystems['st_raderr1'][ind] = 0.0035  # Lillo-Box+ 2020
planetSystems['st_raderr2'][ind] = -0.0035  # Lillo-Box+ 2020

ind = np.argwhere(planetSystems['pl_name'] == 'TOI-1468 b')
planetSystems['pl_orbsmax'][ind] = 0.02102086  # Charturvedi+ 2022

ind = np.argwhere(planetSystems['pl_name'] == 'GJ 1132 b')
planetSystems['pl_orbincl'][ind] = 88.68   # Dittmann+ (2017)

ind = np.argwhere(planetSystems['hostname'] == 'HD 260655')
planetSystems['st_rad'][ind] = 0.439
planetSystems['st_raderr1'][ind] = 0.003
planetSystems['st_raderr2'][ind] = -0.003

ind = np.argwhere(planetSystems['pl_name'] == 'GJ 357 b')
# updating from exoplanet fit to 20s cadence TESS data Sector 35; updated from 120s data from Sector 8
planetSystems['pl_orbper'][ind]      = 3.930607947167463
planetSystems['pl_orbpererr1'][ind]  = 2.51410086e-06
planetSystems['pl_orbpererr2'][ind]  = -2.51410086e-06
planetSystems['pl_tranmid'][ind]     = 2458517.998679131
planetSystems['pl_tranmiderr1'][ind] = 0.0003765
planetSystems['pl_tranmiderr2'][ind] = -0.0003765

ind = np.argwhere(planetSystems['pl_name'] == 'LHS 1140 c')
# updating from exoplanet fit to 20s cadence TESS data Sector 35; updated from 120s data from Sector 8
planetSystems['pl_orbper'][ind]      = 3.777939728
planetSystems['pl_orbpererr1'][ind]  = 5.83523921e-06
planetSystems['pl_orbpererr2'][ind]  = -5.83523921e-06
planetSystems['pl_tranmid'][ind]     = 2458389.2942323
planetSystems['pl_tranmiderr1'][ind] = 0.00062395
planetSystems['pl_tranmiderr2'][ind] = -0.00062395

# refining parameters from Luque & Palle (2022)

# We don't use the Luque & Palle value for TOI-1634 because they basically just took an average of
# two highly discrepant mass measurements. The Cloutier+ (2020) paper is the default and we stick to that,
# meaning that this planet is likely enhance in volatiles and not terrestrial
#ind = np.argwhere(smallPlanetSystems['pl_name'] == 'TOI-1634 b')
#smallPlanetSystems['pl_rade'][ind]      = 1.773
#smallPlanetSystems['pl_radeerr1'][ind]  = 0.077
#smallPlanetSystems['pl_radeerr2'][ind]  = -0.077
#smallPlanetSystems['pl_bmasse'][ind]     = 7.57
#smallPlanetSystems['pl_bmasseerr1'][ind] = 0.71
#smallPlanetSystems['pl_bmasseerr2'][ind] = -0.72

ind = np.argwhere(planetSystems['pl_name'] == 'TOI-1685 b')
planetSystems['pl_rade'][ind]      = 1.70
planetSystems['pl_radeerr1'][ind]  = 0.07
planetSystems['pl_radeerr2'][ind]  = -0.07
planetSystems['pl_bmasse'][ind]     = 3.09
planetSystems['pl_bmasseerr1'][ind] = 0.59
planetSystems['pl_bmasseerr2'][ind] = -0.58

ind = np.argwhere(planetSystems['pl_name'] == 'LHS 1815 b')
planetSystems['pl_rade'][ind]      = 1.088
planetSystems['pl_radeerr1'][ind]  = 0.064
planetSystems['pl_radeerr2'][ind]  = -0.064
planetSystems['pl_bmasse'][ind]     = 1.58
planetSystems['pl_bmasseerr1'][ind] = 0.64
planetSystems['pl_bmasseerr2'][ind] = -0.60

ind = np.argwhere(planetSystems['pl_name'] == 'L 98-59 c')
planetSystems['pl_rade'][ind]      = 1.34
planetSystems['pl_radeerr1'][ind]  = 0.07
planetSystems['pl_radeerr2'][ind]  = -0.07
planetSystems['pl_bmasse'][ind]     = 2.42
planetSystems['pl_bmasseerr1'][ind] = 0.35
planetSystems['pl_bmasseerr2'][ind] = -0.34

ind = np.argwhere(planetSystems['pl_name'] == 'L 98-59 d')
planetSystems['pl_rade'][ind]      = 1.58
planetSystems['pl_radeerr1'][ind]  = 0.08
planetSystems['pl_radeerr2'][ind]  = -0.08
planetSystems['pl_bmasse'][ind]     = 2.31
planetSystems['pl_bmasseerr1'][ind] = 0.46
planetSystems['pl_bmasseerr2'][ind] = -0.45

ind = np.argwhere(planetSystems['pl_name'] == 'TOI-1235 b')
planetSystems['pl_rade'][ind]      = 1.69
planetSystems['pl_radeerr1'][ind]  = 0.08
planetSystems['pl_radeerr2'][ind]  = -0.08
planetSystems['pl_bmasse'][ind]     = 6.69
planetSystems['pl_bmasseerr1'][ind] = 0.67
planetSystems['pl_bmasseerr2'][ind] = -0.69

ind = np.argwhere(planetSystems['pl_name'] == 'LTT 3780 b')
planetSystems['pl_rade'][ind]      = 1.32
planetSystems['pl_radeerr1'][ind]  = 0.06
planetSystems['pl_radeerr2'][ind]  = -0.06
planetSystems['pl_bmasse'][ind]     = 2.47
planetSystems['pl_bmasseerr1'][ind] = 0.24
planetSystems['pl_bmasseerr2'][ind] = -0.24
# also updating orbital paramters from Nowak+ (2020); 
# these are better than the defaults from Cloutier+ (2020) because they were better able to confirm the ephemeris
planetSystems['pl_orbsmax'][ind]      = 0.01203
planetSystems['pl_orbeccen'][ind]     = 0.0640
planetSystems['pl_orbeccenerr1'][ind] = 0.0750
planetSystems['pl_orbeccenerr2'][ind] = -0.0460
planetSystems['pl_orbincl'][ind]      = 85.90
planetSystems['pl_orbper'][ind]       = 0.7683770
planetSystems['pl_orbpererr1'][ind]   = 0.0000014
planetSystems['pl_orbpererr2'][ind]   = -0.0000014
planetSystems['pl_tranmid'][ind]      = 2458543.91281
planetSystems['pl_tranmiderr1'][ind]  = 0.00048
planetSystems['pl_tranmiderr2'][ind]  = -0.00052

ind = np.argwhere(planetSystems['pl_name'] == 'LTT 3780 c')
planetSystems['pl_rade'][ind]      = 2.33
planetSystems['pl_radeerr1'][ind]  = 0.135
planetSystems['pl_radeerr2'][ind]  = -0.135
planetSystems['pl_bmasse'][ind]     = 7.02
planetSystems['pl_bmasseerr1'][ind] = 0.69
planetSystems['pl_bmasseerr2'][ind] = -0.67
# also updating orbital paramters from Nowak+ (2020); 
# these are better than the defaults from Cloutier+ (2020) because they were better able to confirm the ephemeris
planetSystems['pl_orbsmax'][ind]      = 0.0762
planetSystems['pl_orbeccen'][ind]     = 0.115
planetSystems['pl_orbeccenerr1'][ind] = 0.070
planetSystems['pl_orbeccenerr2'][ind] = -0.065
planetSystems['pl_orbincl'][ind]      = 89.08
planetSystems['pl_orbper'][ind]       = 12.252131
planetSystems['pl_orbpererr1'][ind]   = 0.000072
planetSystems['pl_orbpererr2'][ind]   = -0.000064
planetSystems['pl_tranmid'][ind]      = 2458546.8492
planetSystems['pl_tranmiderr1'][ind]  = 0.0016
planetSystems['pl_tranmiderr2'][ind]  = -0.0017 

ind = np.argwhere(planetSystems['pl_name'] == 'GJ 1252 b')
planetSystems['pl_rade'][ind]      = 1.193
planetSystems['pl_radeerr1'][ind]  = 0.074
planetSystems['pl_radeerr2'][ind]  = -0.074
planetSystems['pl_bmasse'][ind]     = 1.32
planetSystems['pl_bmasseerr1'][ind] = 0.28
planetSystems['pl_bmasseerr2'][ind] = -0.28

##############################################
ind = np.argwhere(planetSystems['pl_name'] == 'TOI-1468 c')
planetSystems['pl_orbsmax'][ind] = 0.0859

# %%
samplePlanets = []
for star in sample:
    ind = np.argwhere(star['hostname'] == planetSystems['hostname'])
    for i in ind: samplePlanets.append(planetSystems[i])
samplePlanets = vstack(samplePlanets)

# %%
samplePlanets
# Out:
# <Table length=21>
#  hostname   pl_name   sy_dist    rastr     ... pl_orbeccenerr2 tran_flag rv_flag
#   str16      str18    float64    str12     ...     float64       int64    int64
# --------- ----------- ------- ------------ ... --------------- --------- -------
#   GJ 3473   GJ 3473 b 27.3644 08h02m22.47s ...              --         1       1
#   GJ 3473   GJ 3473 c 27.3644 08h02m22.47s ...              --         0       1
#    GJ 357    GJ 357 b 9.44181 09h36m01.79s ...              --         1       1
#    GJ 357    GJ 357 c 9.44181 09h36m01.79s ...              --         0       1
#    GJ 357    GJ 357 d 9.44181 09h36m01.79s ...              --         0       1
# HD 260655 HD 260655 b 10.0055 06h37m09.97s ...          -0.023         1       1
# HD 260655 HD 260655 c 10.0055 06h37m09.97s ...          -0.022         1       1
#   L 98-59   L 98-59 b 10.6194 08h18m07.89s ...          -0.045         1       1
#   L 98-59   L 98-59 c 10.6194 08h18m07.89s ...          -0.058         1       1
#   L 98-59   L 98-59 d 10.6194 08h18m07.89s ...          -0.046         1       1
#   L 98-59   L 98-59 e 10.6194 08h18m07.89s ...          -0.076         0       1
#  LHS 1140  LHS 1140 b 14.9861 00h44m59.67s ...              --         1       1
#  LHS 1140  LHS 1140 c 14.9861 00h44m59.67s ...              --         1       1
#  LHS 1478  LHS 1478 b 18.2276 02h57m21.33s ...              --         1       1
#  LTT 3780  LTT 3780 b 21.9814 10h18m34.78s ...          -0.046         1       1
#  LTT 3780  LTT 3780 c 21.9814 10h18m34.78s ...          -0.065         1       1
#  TOI-1468  TOI-1468 b 24.7399 01h06m36.93s ...              --         1       1
#  TOI-1468  TOI-1468 c 24.7399 01h06m36.93s ...              --         1       1
#   TOI-270   TOI-270 b 22.4793 04h33m39.86s ...          -0.025         1       1
#   TOI-270   TOI-270 c 22.4793 04h33m39.86s ...          -0.021         1       1
#   TOI-270   TOI-270 d 22.4793 04h33m39.86s ...          -0.023         1       1

# %%
#sampleStars = unique(samplePlanets, 'hostname')
#sampleStars

# %%
def get_bad_occultation(star, plot=False):
    
    starname = star['hostname']
    print(f'Making {starname} system')

    # retrieve all the planets around this star
    inds = np.argwhere(star['hostname'] == samplePlanets['hostname'])
    planets = []
    for i in inds: planets.append(samplePlanets[i])
    planets = vstack(planets)
    
    
    # make the star and planets in starry
    starry_star = make_star(star)
    starry_other_planets = []
    
    # get the index of the "target planet" -- the one in the sample
    target_planet_ind = 0
    for i, pl in enumerate(planets): 
        if pl['pl_name'] in sample['pl_name']: 
            #print(pl['pl_name'], sample['pl_name'])
            print('Target planet index = ', i)
            target_planet_ind += i
            starry_target_planet = make_planet(pl, tidally_locked=False)
            
        else: starry_other_planets.append(make_planet(pl, tidally_locked=False))

    print('Total number of planets = ', len(starry_other_planets)+1)
    
    # cannot figure out how to add an arbitrary number of planets so here we are
    if len(planets)==1: system = st.System(starry_star, starry_target_planet)
    elif len(planets)==2: system = st.System(starry_star, starry_target_planet, starry_other_planets[0])
    elif len(planets)==3: system = st.System(starry_star, starry_target_planet, starry_other_planets[0], starry_other_planets[1])
    elif len(planets)==4: system = st.System(starry_star, starry_target_planet, starry_other_planets[0], starry_other_planets[1], starry_other_planets[2])
    else:
        print('ERROR: You need to add more planet options! (Or figure out a better way to do this)')
        return
    
    # get all of the occultation times in the observing period for the target planet
    target_planet = planets[target_planet_ind]
    target_planet_name = target_planet['pl_name']
    print(f'Finding the bad occultations for {target_planet_name}')

    tdur = orb.Tdur(P=target_planet['pl_orbper']*u.day, 
                    Rp_Rs=((target_planet['pl_rade']*u.R_earth)/(target_planet['st_rad']*u.R_sun)).decompose(),
                    a_Rs = ((target_planet['pl_orbsmax']*u.AU)/(target_planet['st_rad']*u.R_sun)).decompose(),
                    i = target_planet['pl_orbincl']
                    ) # event duration

    start_time = Time("2023-07-01T00:00:00").jd
    end_time   = Time("2025-01-01T00:00:00").jd

    T0 = Time(target_planet['pl_tranmid'], format='jd', scale='utc').value
    start_num = int(np.round((start_time - T0)/target_planet['pl_orbper']))
    end_num   = int(np.round((end_time - T0)/target_planet['pl_orbper']))
    event_num = np.arange(start_num, end_num+1)

    t0p5s = target_planet['pl_tranmid'] + (event_num+0.5)*target_planet['pl_orbper']
    
    # get the transit/occultation events of the other planets in the system
    other_events = []
    for i, other_planet in enumerate(planets):
        if i == target_planet_ind: continue
        if other_planet['tran_flag'] == 0: 
            print('Careful, planet', other_planet['pl_name'], 'does not appear to transit')
            continue

        T0 = Time(other_planet['pl_tranmid'], format='jd', scale='utc').value
        start_num = int(np.round((start_time - T0)/other_planet['pl_orbper']))
        end_num   = int(np.round((end_time - T0)/other_planet['pl_orbper']))
        event_num = np.arange(start_num, end_num+1)

        transits = other_planet['pl_tranmid'] + event_num*other_planet['pl_orbper']
        eclipses = other_planet['pl_tranmid'] + (event_num+0.5)*other_planet['pl_orbper']
        
        other_events.append(transits)
        other_events.append(eclipses)

    try: other_events = np.sort(np.hstack(other_events))
    except: 
        print(f'Number of bad occultations = for {target_planet_name}', 0, 'out of', len(t0p5s))
        return
    
    # find the overlapping events with the target occultations
    n_bad_events = 0
    for t_occ in t0p5s:
        t_start = t_occ - 3*tdur.to(u.day).value
        t_end   = t_occ + 3*tdur.to(u.day).value
        time = np.linspace(t_start, t_end, 1000)

        # get closest event to occulation
        event_ind = np.argmin(abs(t_occ - other_events))
        closest_event = other_events[event_ind]

        if closest_event >= t_start and closest_event <= t_end:

            flux = np.hstack(system.flux(time))

            if plot: 
                plt.plot(time, flux)
                plt.xlabel('Time (days)')
                plt.ylabel('Relative Flux')
                plt.show()
        
            
            #print('    Do not observe between:', t_start, 'and', t_end)
            bad_time_start = Time(t_start, format='jd', scale='utc').iso
            bad_time_end   = Time(t_end, format='jd', scale='utc').iso
            print('    Do not observe between:', bad_time_start, 'and', bad_time_end)
            n_bad_events += 1
            
    print(f'Number of bad occultations = for {target_planet_name}:', n_bad_events, '/', len(t0p5s), f'; approx {int(np.round(n_bad_events/len(t0p5s)*100))} %')

# %%
for target in sample: get_bad_occultation(target)
# Out:
# Making GJ 3473 system
# Target planet index =  0
# Total number of planets =  2
# Finding the bad occultations for GJ 3473 b
# Careful, planet GJ 3473 c does not appear to transit
# Number of bad occultations = for GJ 3473 b 0 out of 460
# Making GJ 357 system
# Target planet index =  0
# Total number of planets =  3
# Finding the bad occultations for GJ 357 b
# Careful, planet GJ 357 c does not appear to transit
# Careful, planet GJ 357 d does not appear to transit
# Number of bad occultations = for GJ 357 b 0 out of 141
# Making HD 260655 system
# Target planet index =  0
# Total number of planets =  2
# Finding the bad occultations for HD 260655 b
#     Do not observe between: 2023-08-15 15:31:06.555 and 2023-08-15 22:26:15.909
#     Do not observe between: 2023-08-18 09:59:13.947 and 2023-08-18 16:54:23.301
#     Do not observe between: 2023-08-21 04:27:21.339 and 2023-08-21 11:22:30.693
#     Do not observe between: 2023-11-17 19:27:17.883 and 2023-11-18 02:22:27.237
#     Do not observe between: 2023-11-20 13:55:25.275 and 2023-11-20 20:50:34.629
#     Do not observe between: 2023-11-23 08:23:32.667 and 2023-11-23 15:18:42.021
#     Do not observe between: 2024-02-19 23:23:29.211 and 2024-02-20 06:18:38.565
#     Do not observe between: 2024-02-22 17:51:36.603 and 2024-02-23 00:46:45.957
#     Do not observe between: 2024-02-25 12:19:43.995 and 2024-02-25 19:14:53.349
#     Do not observe between: 2024-02-28 06:47:51.387 and 2024-02-28 13:43:00.741
#     Do not observe between: 2024-05-24 03:19:40.539 and 2024-05-24 10:14:49.893
#     Do not observe between: 2024-05-26 21:47:47.931 and 2024-05-27 04:42:57.285
#     Do not observe between: 2024-05-29 16:15:55.323 and 2024-05-29 23:11:04.677
#     Do not observe between: 2024-06-01 10:44:02.715 and 2024-06-01 17:39:12.069
#     Do not observe between: 2024-08-26 07:15:51.867 and 2024-08-26 14:11:01.221
#     Do not observe between: 2024-08-29 01:43:59.259 and 2024-08-29 08:39:08.613
#     Do not observe between: 2024-08-31 20:12:06.651 and 2024-09-01 03:07:16.005
#     Do not observe between: 2024-09-03 14:40:14.043 and 2024-09-03 21:35:23.397
#     Do not observe between: 2024-12-01 05:40:10.587 and 2024-12-01 12:35:19.941
#     Do not observe between: 2024-12-04 00:08:17.979 and 2024-12-04 07:03:27.333
#     Do not observe between: 2024-12-06 18:36:25.371 and 2024-12-07 01:31:34.725
# Number of bad occultations = for HD 260655 b: 21 / 200 ; approx 10 %
# Making L 98-59 system
# Target planet index =  1
# Total number of planets =  4
# Finding the bad occultations for L 98-59 c
# Careful, planet L 98-59 e does not appear to transit
#     Do not observe between: 2023-07-26 02:16:06.855 and 2023-07-26 08:07:10.166
#     Do not observe between: 2023-08-09 20:34:25.069 and 2023-08-10 02:25:28.379
#     Do not observe between: 2023-09-04 16:36:26.942 and 2023-09-04 22:27:30.252
#     Do not observe between: 2023-09-19 10:54:45.155 and 2023-09-19 16:45:48.466
#     Do not observe between: 2023-09-30 12:38:28.814 and 2023-09-30 18:29:32.125
#     Do not observe between: 2023-10-07 21:47:37.921 and 2023-10-08 03:38:41.232
#     Do not observe between: 2023-10-11 14:22:12.474 and 2023-10-11 20:13:15.785
#     Do not observe between: 2023-10-15 06:56:47.028 and 2023-10-15 12:47:50.338
#     Do not observe between: 2023-10-18 23:31:21.581 and 2023-10-19 05:22:24.892
#     Do not observe between: 2023-10-22 16:05:56.134 and 2023-10-22 21:56:59.445
#     Do not observe between: 2023-10-26 08:40:30.687 and 2023-10-26 14:31:33.998
#     Do not observe between: 2023-10-30 01:15:05.241 and 2023-10-30 07:06:08.552
#     Do not observe between: 2023-11-10 02:58:48.901 and 2023-11-10 08:49:52.211
#     Do not observe between: 2023-11-24 21:17:07.114 and 2023-11-25 03:08:10.425
#     Do not observe between: 2023-12-05 23:00:50.774 and 2023-12-06 04:51:54.084
#     Do not observe between: 2023-12-20 17:19:08.987 and 2023-12-20 23:10:12.298
#     Do not observe between: 2024-01-04 11:37:27.200 and 2024-01-04 17:28:30.511
#     Do not observe between: 2024-01-15 13:21:10.860 and 2024-01-15 19:12:14.170
#     Do not observe between: 2024-01-30 07:39:29.073 and 2024-01-30 13:30:32.384
#     Do not observe between: 2024-02-25 03:41:30.946 and 2024-02-25 09:32:34.257
#     Do not observe between: 2024-03-10 21:59:49.159 and 2024-03-11 03:50:52.470
#     Do not observe between: 2024-03-21 23:43:32.819 and 2024-03-22 05:34:36.130
#     Do not observe between: 2024-04-05 18:01:51.032 and 2024-04-05 23:52:54.343
#     Do not observe between: 2024-05-01 14:03:52.905 and 2024-05-01 19:54:56.216
#     Do not observe between: 2024-05-16 08:22:11.118 and 2024-05-16 14:13:14.429
#     Do not observe between: 2024-06-11 04:24:12.991 and 2024-06-11 10:15:16.302
#     Do not observe between: 2024-06-25 22:42:31.204 and 2024-06-26 04:33:34.515
#     Do not observe between: 2024-07-07 00:26:14.864 and 2024-07-07 06:17:18.175
#     Do not observe between: 2024-07-21 18:44:33.077 and 2024-07-22 00:35:36.388
#     Do not observe between: 2024-08-16 14:46:34.950 and 2024-08-16 20:37:38.261
#     Do not observe between: 2024-08-31 09:04:53.163 and 2024-08-31 14:55:56.474
#     Do not observe between: 2024-09-26 05:06:55.036 and 2024-09-26 10:57:58.347
#     Do not observe between: 2024-10-10 23:25:13.249 and 2024-10-11 05:16:16.560
#     Do not observe between: 2024-10-22 01:08:56.909 and 2024-10-22 07:00:00.220
#     Do not observe between: 2024-11-05 19:27:15.122 and 2024-11-06 01:18:18.433
#     Do not observe between: 2024-11-09 12:01:49.675 and 2024-11-09 17:52:52.986
#     Do not observe between: 2024-11-13 04:36:24.229 and 2024-11-13 10:27:27.539
#     Do not observe between: 2024-11-16 21:10:58.782 and 2024-11-17 03:02:02.093
#     Do not observe between: 2024-11-20 13:45:33.335 and 2024-11-20 19:36:36.646
#     Do not observe between: 2024-11-24 06:20:07.888 and 2024-11-24 12:11:11.199
#     Do not observe between: 2024-11-27 22:54:42.442 and 2024-11-28 04:45:45.753
#     Do not observe between: 2024-12-01 15:29:16.995 and 2024-12-01 21:20:20.306
#     Do not observe between: 2024-12-16 09:47:35.208 and 2024-12-16 15:38:38.519
# Number of bad occultations = for L 98-59 c: 43 / 150 ; approx 29 %
# Making LHS 1140 system
# Target planet index =  1
# Total number of planets =  2
# Finding the bad occultations for LHS 1140 c
#     Do not observe between: 2023-09-05 15:00:07.518 and 2023-09-05 21:29:58.660
#     Do not observe between: 2024-08-29 12:42:16.805 and 2024-08-29 19:12:07.948
# Number of bad occultations = for LHS 1140 c: 2 / 146 ; approx 1 %
# Making LHS 1478 system
# Target planet index =  0
# Total number of planets =  1
# Finding the bad occultations for LHS 1478 b
# Number of bad occultations = for LHS 1478 b 0 out of 283
# Making LTT 3780 system
# Target planet index =  0
# Total number of planets =  2
# Finding the bad occultations for LTT 3780 b
#     Do not observe between: 2023-08-07 10:34:07.459 and 2023-08-07 15:08:44.006
#     Do not observe between: 2023-08-13 14:05:49.642 and 2023-08-13 18:40:26.189
#     Do not observe between: 2023-08-19 17:37:31.824 and 2023-08-19 22:12:08.371
#     Do not observe between: 2023-08-25 21:09:14.007 and 2023-08-26 01:43:50.553
#     Do not observe between: 2023-09-01 00:40:56.189 and 2023-09-01 05:15:32.736
#     Do not observe between: 2023-09-07 04:12:38.371 and 2023-09-07 08:47:14.918
#     Do not observe between: 2023-09-13 07:44:20.554 and 2023-09-13 12:18:57.101
#     Do not observe between: 2023-09-19 11:16:02.736 and 2023-09-19 15:50:39.283
#     Do not observe between: 2023-09-25 14:47:44.919 and 2023-09-25 19:22:21.465
#     Do not observe between: 2023-10-01 18:19:27.101 and 2023-10-01 22:54:03.648
#     Do not observe between: 2024-03-21 02:40:40.435 and 2024-03-21 07:15:16.982
#     Do not observe between: 2024-03-27 06:12:22.618 and 2024-03-27 10:46:59.165
#     Do not observe between: 2024-04-02 09:44:04.800 and 2024-04-02 14:18:41.347
#     Do not observe between: 2024-04-08 13:15:46.983 and 2024-04-08 17:50:23.529
#     Do not observe between: 2024-04-14 16:47:29.165 and 2024-04-14 21:22:05.712
#     Do not observe between: 2024-04-20 20:19:11.347 and 2024-04-21 00:53:47.894
#     Do not observe between: 2024-04-26 23:50:53.530 and 2024-04-27 04:25:30.077
#     Do not observe between: 2024-05-03 03:22:35.712 and 2024-05-03 07:57:12.259
#     Do not observe between: 2024-05-09 06:54:17.895 and 2024-05-09 11:28:54.441
#     Do not observe between: 2024-11-02 18:47:13.411 and 2024-11-02 23:21:49.958
#     Do not observe between: 2024-11-08 22:18:55.594 and 2024-11-09 02:53:32.141
#     Do not observe between: 2024-11-15 01:50:37.776 and 2024-11-15 06:25:14.323
#     Do not observe between: 2024-11-21 05:22:19.959 and 2024-11-21 09:56:56.505
#     Do not observe between: 2024-11-27 08:54:02.141 and 2024-11-27 13:28:38.688
#     Do not observe between: 2024-12-03 12:25:44.323 and 2024-12-03 17:00:20.870
#     Do not observe between: 2024-12-09 15:57:26.506 and 2024-12-09 20:32:03.053
#     Do not observe between: 2024-12-15 19:29:08.688 and 2024-12-16 00:03:45.235
#     Do not observe between: 2024-12-21 23:00:50.871 and 2024-12-22 03:35:27.417
# Number of bad occultations = for LTT 3780 b: 28 / 716 ; approx 4 %
# Making TOI-1468 system
# Target planet index =  0
# Total number of planets =  2
# Finding the bad occultations for TOI-1468 b
#     Do not observe between: 2023-07-08 02:57:08.679 and 2023-07-08 09:15:37.516
#     Do not observe between: 2023-09-08 04:19:09.055 and 2023-09-08 10:37:37.893
#     Do not observe between: 2023-11-01 17:09:23.931 and 2023-11-01 23:27:52.769
#     Do not observe between: 2024-01-02 18:31:24.308 and 2024-01-03 00:49:53.145
#     Do not observe between: 2024-03-04 19:53:24.684 and 2024-03-05 02:11:53.521
#     Do not observe between: 2024-04-28 08:43:39.560 and 2024-04-28 15:02:08.398
#     Do not observe between: 2024-06-29 10:05:39.937 and 2024-06-29 16:24:08.774
#     Do not observe between: 2024-08-30 11:27:40.313 and 2024-08-30 17:46:09.150
#     Do not observe between: 2024-10-24 00:17:55.189 and 2024-10-24 06:36:24.026
#     Do not observe between: 2024-10-31 12:49:40.689 and 2024-10-31 19:08:09.526
#     Do not observe between: 2024-12-25 01:39:55.565 and 2024-12-25 07:58:24.403
# Number of bad occultations = for TOI-1468 b: 11 / 293 ; approx 4 %
# Making TOI-270 system
# Target planet index =  0
# Total number of planets =  3
# Finding the bad occultations for TOI-270 b
#     Do not observe between: 2023-07-27 04:14:06.820 and 2023-07-27 12:50:47.845
#     Do not observe between: 2023-08-12 23:27:13.261 and 2023-08-13 08:03:54.286
#     Do not observe between: 2023-08-19 16:44:27.838 and 2023-08-20 01:21:08.863
#     Do not observe between: 2023-09-05 11:57:34.279 and 2023-09-05 20:34:15.305
#     Do not observe between: 2023-09-18 22:32:03.433 and 2023-09-19 07:08:44.458
#     Do not observe between: 2023-10-05 17:45:09.874 and 2023-10-06 02:21:50.899
#     Do not observe between: 2023-11-01 14:54:08.181 and 2023-11-01 23:30:49.206
#     Do not observe between: 2023-11-11 16:50:00.046 and 2023-11-12 01:26:41.071
#     Do not observe between: 2023-11-28 12:03:06.487 and 2023-11-28 20:39:47.513
#     Do not observe between: 2024-01-04 11:07:56.659 and 2024-01-04 19:44:37.684
#     Do not observe between: 2024-01-14 13:03:48.524 and 2024-01-14 21:40:29.549
#     Do not observe between: 2024-01-21 06:21:03.101 and 2024-01-21 14:57:44.126
#     Do not observe between: 2024-02-27 05:25:53.272 and 2024-02-27 14:02:34.297
#     Do not observe between: 2024-03-15 00:38:59.714 and 2024-03-15 09:15:40.739
#     Do not observe between: 2024-03-28 11:13:28.867 and 2024-03-28 19:50:09.892
#     Do not observe between: 2024-04-20 23:43:49.885 and 2024-04-21 08:20:30.910
#     Do not observe between: 2024-05-07 18:56:56.327 and 2024-05-08 03:33:37.352
#     Do not observe between: 2024-06-10 09:23:09.210 and 2024-06-10 17:59:50.235
#     Do not observe between: 2024-06-13 18:01:46.498 and 2024-06-14 02:38:27.523
#     Do not observe between: 2024-06-30 13:14:52.940 and 2024-06-30 21:51:33.965
#     Do not observe between: 2024-07-20 17:06:36.670 and 2024-07-21 01:43:17.695
#     Do not observe between: 2024-08-06 12:19:43.111 and 2024-08-06 20:56:24.137
#     Do not observe between: 2024-08-23 07:32:49.553 and 2024-08-23 16:09:30.578
#     Do not observe between: 2024-09-12 11:24:33.283 and 2024-09-12 20:01:14.308
#     Do not observe between: 2024-09-29 06:37:39.725 and 2024-09-29 15:14:20.750
#     Do not observe between: 2024-10-19 10:29:23.454 and 2024-10-19 19:06:04.480
#     Do not observe between: 2024-11-05 05:42:29.896 and 2024-11-05 14:19:10.921
#     Do not observe between: 2024-11-22 00:55:36.338 and 2024-11-22 09:32:17.363
#     Do not observe between: 2024-12-29 00:00:26.509 and 2024-12-29 08:37:07.534
#     Do not observe between: 2025-01-01 08:39:03.798 and 2025-01-01 17:15:44.823
# Number of bad occultations = for TOI-270 b: 30 / 164 ; approx 18 %

# %%
get_bad_occultation(sample[6])
# Out:
# Making LTT 3780 system
# Target planet index =  0
# Total number of planets =  2
# Finding the bad occultations for LTT 3780 b
#     Do not observe between: 2023-08-07 10:34:07.459 and 2023-08-07 15:08:44.006
#     Do not observe between: 2023-08-13 14:05:49.642 and 2023-08-13 18:40:26.189
#     Do not observe between: 2023-08-19 17:37:31.824 and 2023-08-19 22:12:08.371
#     Do not observe between: 2023-08-25 21:09:14.007 and 2023-08-26 01:43:50.553
#     Do not observe between: 2023-09-01 00:40:56.189 and 2023-09-01 05:15:32.736
#     Do not observe between: 2023-09-07 04:12:38.371 and 2023-09-07 08:47:14.918
#     Do not observe between: 2023-09-13 07:44:20.554 and 2023-09-13 12:18:57.101
#     Do not observe between: 2023-09-19 11:16:02.736 and 2023-09-19 15:50:39.283
#     Do not observe between: 2023-09-25 14:47:44.919 and 2023-09-25 19:22:21.465
#     Do not observe between: 2023-10-01 18:19:27.101 and 2023-10-01 22:54:03.648
#     Do not observe between: 2024-03-21 02:40:40.435 and 2024-03-21 07:15:16.982
#     Do not observe between: 2024-03-27 06:12:22.618 and 2024-03-27 10:46:59.165
#     Do not observe between: 2024-04-02 09:44:04.800 and 2024-04-02 14:18:41.347
#     Do not observe between: 2024-04-08 13:15:46.983 and 2024-04-08 17:50:23.529
#     Do not observe between: 2024-04-14 16:47:29.165 and 2024-04-14 21:22:05.712
#     Do not observe between: 2024-04-20 20:19:11.347 and 2024-04-21 00:53:47.894
#     Do not observe between: 2024-04-26 23:50:53.530 and 2024-04-27 04:25:30.077
#     Do not observe between: 2024-05-03 03:22:35.712 and 2024-05-03 07:57:12.259
#     Do not observe between: 2024-05-09 06:54:17.895 and 2024-05-09 11:28:54.441
#     Do not observe between: 2024-11-02 18:47:13.411 and 2024-11-02 23:21:49.958
#     Do not observe between: 2024-11-08 22:18:55.594 and 2024-11-09 02:53:32.141
#     Do not observe between: 2024-11-15 01:50:37.776 and 2024-11-15 06:25:14.323
#     Do not observe between: 2024-11-21 05:22:19.959 and 2024-11-21 09:56:56.505
#     Do not observe between: 2024-11-27 08:54:02.141 and 2024-11-27 13:28:38.688
#     Do not observe between: 2024-12-03 12:25:44.323 and 2024-12-03 17:00:20.870
#     Do not observe between: 2024-12-09 15:57:26.506 and 2024-12-09 20:32:03.053
#     Do not observe between: 2024-12-15 19:29:08.688 and 2024-12-16 00:03:45.235
#     Do not observe between: 2024-12-21 23:00:50.871 and 2024-12-22 03:35:27.417
# Number of bad occultations = for LTT 3780 b: 28 / 716 ; approx 4 %

# %%
star = sample[4]

starname = star['hostname']
print(f'Making {starname} system')

# retrieve all the planets around this star
inds = np.argwhere(star['hostname'] == samplePlanets['hostname'])
planets = []
for i in inds: planets.append(samplePlanets[i])
planets = vstack(planets)
print(planets)

# make the star and planets in starry
starry_star = make_star(star)
starry_other_planets = []

# get the index of the "target planet" -- the one in the sample
target_planet_ind = 0
for i, pl in enumerate(planets): 
    if pl['pl_name'] in sample['pl_name']: 
        #print(pl['pl_name'], sample['pl_name'])
        print('Target planet index = ', i)
        target_planet = pl
        target_planet_name = pl['pl_name']
        starry_target_planet = make_planet(pl, tidally_locked=False)

    else: starry_other_planets.append(make_planet(pl, tidally_locked=False))

print('Total number of planets = ', len(starry_other_planets)+1)

# cannot figure out how to add an arbitrary number of planets so here we are
if len(planets)==1: system = st.System(starry_star, starry_target_planet)
elif len(planets)==2: system = st.System(starry_star, starry_target_planet, starry_other_planets[0])
elif len(planets)==3: system = st.System(starry_star, starry_target_planet, starry_other_planets[0], starry_other_planets[1])
elif len(planets)==4: system = st.System(starry_star, starry_target_planet, starry_other_planets[0], starry_other_planets[1], starry_other_planets[2])
else:
    print('ERROR: You need to add more planet options! (Or figure out a better way to do this)')
    

# get all of the occultation times in the observing period for the target planet
print(f'Finding the bad occultations for {target_planet_name}')
# Out:
# Making LHS 1140 system
# hostname  pl_name   sy_dist    rastr     ... pl_orbeccenerr2 tran_flag rv_flag
# -------- ---------- ------- ------------ ... --------------- --------- -------
# LHS 1140 LHS 1140 b 14.9861 00h44m59.67s ...              --         1       1
# LHS 1140 LHS 1140 c 14.9861 00h44m59.67s ...              --         1       1
# Target planet index =  1
# Total number of planets =  2
# Finding the bad occultations for LHS 1140 c

# %%
tdur = orb.Tdur(P=target_planet['pl_orbper']*u.day, 
                Rp_Rs=((target_planet['pl_rade']*u.R_earth)/(target_planet['st_rad']*u.R_sun)).decompose(),
                a_Rs = ((target_planet['pl_orbsmax']*u.AU)/(target_planet['st_rad']*u.R_sun)).decompose(),
                i = target_planet['pl_orbincl']
                ) # event duration

start_time = Time("2023-07-01T00:00:00").jd
end_time   = Time("2025-01-01T00:00:00").jd

T0 = Time(target_planet['pl_tranmid'], format='jd', scale='utc').value
start_num = int(np.round((start_time - T0)/target_planet['pl_orbper']))
end_num   = int(np.round((end_time - T0)/target_planet['pl_orbper']))
event_num = np.arange(start_num, end_num+1)

t0p5s = target_planet['pl_tranmid'] + event_num*target_planet['pl_orbper'] + 0.5*target_planet['pl_orbper']

# %%
# %matplotlib inline
occ_time = t0p5s[0]
start, end = occ_time - 1, occ_time + 1
time = np.linspace(start, end, 1000)
#time = np.linspace(target_planet['pl_tranmid'], target_planet['pl_tranmid']+5, 1000)
#time = np.linspace(0, 3, 1000)

flux = np.hstack(system.flux(time))

plt.plot(time/target_planet['pl_orbper'], flux)
#plt.ylim(1.0049999999, 1.0050000001)

# %%
other_events = []
for i, other_planet in enumerate(planets):
    if i == target_planet_ind: continue
        
    T0 = Time(other_planet['pl_tranmid'], format='jd', scale='utc').value
    start_num = int(np.round((start_time - T0)/other_planet['pl_orbper']))
    end_num   = int(np.round((end_time - T0)/other_planet['pl_orbper']))
    event_num = np.arange(start_num, end_num+1)

    transits = other_planet['pl_tranmid'] + event_num*other_planet['pl_orbper']
    eclipses = other_planet['pl_tranmid'] + event_num*other_planet['pl_orbper'] + 0.5*other_planet['pl_orbper']
    
    other_events.append(transits)
    other_events.append(eclipses)
    
other_events = np.sort(np.hstack(other_events))

# %%
# find the overlapping events with the target occultations
n_bad_events = 0
for t_occ in t0p5s:
    t_start = t_occ - 3*tdur.to(u.day).value
    t_end   = t_occ + 3*tdur.to(u.day).value
    #t_start = -3*tdur.to(u.day).value
    #t_end   =  3*tdur.to(u.day).value
    time = np.linspace(t_start, t_end, 1000)

    # get closest event to occulation
    event_ind = np.argmin(abs(t_occ - other_events))
    closest_event = other_events[event_ind]

    #if closest_event >= t_start and closest_event <= t_end:

    flux = np.hstack(system.flux(time))

    plt.plot(time, flux)
    plt.show()

    print('Do not observe between:', t_start, 'and', t_end)
    n_bad_events += 1

print(f'Number of bad occultations = for {target_planet_name}', n_bad_events, 'out of', len(t0p5s))
# Out:
# Do not observe between: 2460128.9001116343 and 2460129.170842454
# Do not observe between: 2460132.6780513623 and 2460132.948782182
# Do not observe between: 2460136.4559910903 and 2460136.72672191
# Do not observe between: 2460140.2339308183 and 2460140.504661638
# Do not observe between: 2460144.0118705463 and 2460144.282601366
# Do not observe between: 2460147.7898102743 and 2460148.060541094
# Do not observe between: 2460151.5677500023 and 2460151.838480822
# Do not observe between: 2460155.3456897303 and 2460155.61642055
# Do not observe between: 2460159.1236294582 and 2460159.394360278
# Do not observe between: 2460162.9015691862 and 2460163.172300006
# Do not observe between: 2460166.6795089142 and 2460166.950239734
# Do not observe between: 2460170.4574486427 and 2460170.7281794623
# Do not observe between: 2460174.2353883707 and 2460174.5061191902
# Do not observe between: 2460178.0133280987 and 2460178.2840589182
# Do not observe between: 2460181.7912678267 and 2460182.0619986462
# Do not observe between: 2460185.5692075547 and 2460185.8399383742
# Do not observe between: 2460189.3471472827 and 2460189.617878102
# Do not observe between: 2460193.1250870107 and 2460193.39581783
# Do not observe between: 2460196.9030267387 and 2460197.173757558
# Do not observe between: 2460200.6809664667 and 2460200.951697286
# Do not observe between: 2460204.4589061947 and 2460204.729637014
# Do not observe between: 2460208.2368459227 and 2460208.507576742
# Do not observe between: 2460212.0147856507 and 2460212.28551647
# Do not observe between: 2460215.7927253786 and 2460216.063456198
# Do not observe between: 2460219.5706651066 and 2460219.841395926
# Do not observe between: 2460223.3486048346 and 2460223.619335654
# Do not observe between: 2460227.1265445626 and 2460227.397275382
# Do not observe between: 2460230.9044842906 and 2460231.17521511
# Do not observe between: 2460234.6824240186 and 2460234.953154838
# Do not observe between: 2460238.4603637466 and 2460238.731094566
# Do not observe between: 2460242.2383034746 and 2460242.509034294
# Do not observe between: 2460246.0162432026 and 2460246.286974022
# Do not observe between: 2460249.7941829306 and 2460250.06491375
# Do not observe between: 2460253.5721226586 and 2460253.842853478
# Do not observe between: 2460257.3500623866 and 2460257.620793206
# Do not observe between: 2460261.1280021146 and 2460261.398732934
# Do not observe between: 2460264.9059418426 and 2460265.176672662
# Do not observe between: 2460268.6838815706 and 2460268.95461239
# Do not observe between: 2460272.4618212986 and 2460272.732552118
# Do not observe between: 2460276.2397610266 and 2460276.510491846
# Do not observe between: 2460280.0177007546 and 2460280.288431574
# Do not observe between: 2460283.7956404826 and 2460284.066371302
# Do not observe between: 2460287.5735802106 and 2460287.84431103
# Do not observe between: 2460291.3515199386 and 2460291.622250758
# Do not observe between: 2460295.1294596666 and 2460295.400190486
# Do not observe between: 2460298.9073993945 and 2460299.178130214
# Do not observe between: 2460302.6853391225 and 2460302.956069942
# Do not observe between: 2460306.4632788505 and 2460306.73400967
# Do not observe between: 2460310.2412185785 and 2460310.511949398
# Do not observe between: 2460314.0191583065 and 2460314.289889126
# Do not observe between: 2460317.7970980345 and 2460318.067828854
# Do not observe between: 2460321.5750377625 and 2460321.845768582
# Do not observe between: 2460325.3529774905 and 2460325.62370831
# Do not observe between: 2460329.1309172185 and 2460329.401648038
# Do not observe between: 2460332.9088569465 and 2460333.179587766
# Do not observe between: 2460336.6867966745 and 2460336.957527494
# Do not observe between: 2460340.4647364025 and 2460340.735467222
# Do not observe between: 2460344.2426761305 and 2460344.51340695
# Do not observe between: 2460348.0206158585 and 2460348.291346678
# Do not observe between: 2460351.7985555865 and 2460352.069286406
# Do not observe between: 2460355.5764953145 and 2460355.847226134
# Do not observe between: 2460359.3544350425 and 2460359.625165862
# Do not observe between: 2460363.1323747705 and 2460363.40310559
# Do not observe between: 2460366.9103144985 and 2460367.181045318
# Do not observe between: 2460370.6882542265 and 2460370.958985046
# Do not observe between: 2460374.4661939545 and 2460374.736924774
# Do not observe between: 2460378.2441336825 and 2460378.514864502
# Do not observe between: 2460382.0220734105 and 2460382.29280423
# Do not observe between: 2460385.8000131384 and 2460386.070743958
# Do not observe between: 2460389.5779528664 and 2460389.848683686
# Do not observe between: 2460393.3558925944 and 2460393.626623414
# Do not observe between: 2460397.1338323224 and 2460397.404563142
# Do not observe between: 2460400.9117720504 and 2460401.18250287
# Do not observe between: 2460404.6897117784 and 2460404.960442598
# Do not observe between: 2460408.4676515064 and 2460408.738382326
# Do not observe between: 2460412.2455912344 and 2460412.516322054
# Do not observe between: 2460416.0235309624 and 2460416.294261782
# Do not observe between: 2460419.8014706904 and 2460420.07220151
# Do not observe between: 2460423.5794104184 and 2460423.850141238
# Do not observe between: 2460427.3573501464 and 2460427.628080966
# Do not observe between: 2460431.1352898744 and 2460431.406020694
# Do not observe between: 2460434.9132296024 and 2460435.183960422
# Do not observe between: 2460438.6911693304 and 2460438.96190015
# Do not observe between: 2460442.4691090584 and 2460442.739839878
# Do not observe between: 2460446.2470487864 and 2460446.517779606
# Do not observe between: 2460450.0249885144 and 2460450.295719334
# Do not observe between: 2460453.8029282424 and 2460454.073659062
# Do not observe between: 2460457.5808679704 and 2460457.85159879
# Do not observe between: 2460461.3588076984 and 2460461.629538518
# Do not observe between: 2460465.1367474264 and 2460465.407478246
# Do not observe between: 2460468.9146871543 and 2460469.185417974
# Do not observe between: 2460472.6926268823 and 2460472.963357702
# Do not observe between: 2460476.4705666103 and 2460476.74129743
# Do not observe between: 2460480.2485063383 and 2460480.519237158
# Do not observe between: 2460484.0264460663 and 2460484.297176886
# Do not observe between: 2460487.8043857943 and 2460488.075116614
# Do not observe between: 2460491.5823255223 and 2460491.853056342
# Do not observe between: 2460495.3602652503 and 2460495.63099607
# Do not observe between: 2460499.1382049783 and 2460499.408935798
# Do not observe between: 2460502.9161447063 and 2460503.186875526
# Do not observe between: 2460506.6940844343 and 2460506.964815254
# Do not observe between: 2460510.4720241623 and 2460510.742754982
# Do not observe between: 2460514.2499638903 and 2460514.52069471
# Do not observe between: 2460518.0279036183 and 2460518.298634438
# Do not observe between: 2460521.8058433463 and 2460522.076574166
# Do not observe between: 2460525.5837830743 and 2460525.854513894
# Do not observe between: 2460529.3617228023 and 2460529.632453622
# Do not observe between: 2460533.1396625303 and 2460533.41039335
# Do not observe between: 2460536.9176022583 and 2460537.188333078
# Do not observe between: 2460540.6955419863 and 2460540.966272806
# Do not observe between: 2460544.4734817143 and 2460544.744212534
# Do not observe between: 2460548.2514214423 and 2460548.522152262
# Do not observe between: 2460552.0293611703 and 2460552.30009199
# Do not observe between: 2460555.8073008982 and 2460556.078031718
# Do not observe between: 2460559.5852406262 and 2460559.855971446
# Do not observe between: 2460563.3631803547 and 2460563.6339111743
# Do not observe between: 2460567.1411200827 and 2460567.4118509023
# Do not observe between: 2460570.9190598107 and 2460571.1897906302
# Do not observe between: 2460574.6969995387 and 2460574.9677303582
# Do not observe between: 2460578.4749392667 and 2460578.7456700862
# Do not observe between: 2460582.2528789947 and 2460582.5236098142
# Do not observe between: 2460586.0308187227 and 2460586.301549542
# Do not observe between: 2460589.8087584507 and 2460590.07948927
# Do not observe between: 2460593.5866981787 and 2460593.857428998
# Do not observe between: 2460597.3646379067 and 2460597.635368726
# Do not observe between: 2460601.1425776347 and 2460601.413308454
# Do not observe between: 2460604.9205173627 and 2460605.191248182
# Do not observe between: 2460608.6984570906 and 2460608.96918791
# Do not observe between: 2460612.4763968186 and 2460612.747127638
# Do not observe between: 2460616.2543365466 and 2460616.525067366
# Do not observe between: 2460620.0322762746 and 2460620.303007094
# Do not observe between: 2460623.8102160026 and 2460624.080946822
# Do not observe between: 2460627.5881557306 and 2460627.85888655
# Do not observe between: 2460631.3660954586 and 2460631.636826278
# Do not observe between: 2460635.1440351866 and 2460635.414766006
# Do not observe between: 2460638.9219749146 and 2460639.192705734
# Do not observe between: 2460642.6999146426 and 2460642.970645462
# Do not observe between: 2460646.4778543706 and 2460646.74858519
# Do not observe between: 2460650.2557940986 and 2460650.526524918
# Do not observe between: 2460654.0337338266 and 2460654.304464646
# Do not observe between: 2460657.8116735546 and 2460658.082404374
# Do not observe between: 2460661.5896132826 and 2460661.860344102
# Do not observe between: 2460665.3675530106 and 2460665.63828383
# Do not observe between: 2460669.1454927386 and 2460669.416223558
# Do not observe between: 2460672.9234324666 and 2460673.194163286
# Do not observe between: 2460676.7013721946 and 2460676.972103014
# Number of bad occultations = for LHS 1140 c 146 out of 146
